# %% [markdown]
# <hr style="border:5px solid #108999"> </hr>

# %% [markdown]
# # List Comprehensions and Lambda Functions <hr style="border:4.5px solid #108999"> </hr>

# %% [markdown]
# ## List Comprehensions

# %% [markdown]
# Execute the code cell below to create the following three lists: **products_on_sale**, **sale_prices**, **quantities**

# %%
products_on_sale = ['Chair_Type_1', 'Chair_Type_2', 'Chair_Type_3', 'Chair_Type_4']
sale_prices = [100, 120, 135, 150]
quantities = [1000, 1500, 1300]

# %% [markdown]
# The following code cell will execute a nested loop that will deliver all possible combinations of the elements from the **products_on_sale**, **sale_prices** and **quantities** lists:

# %%
for chair_type in products_on_sale:
    for price in sale_prices:
        for quantity in quantities:
            print ([chair_type, price*quantity])
# Out:
# ['Chair_Type_1', 100000]
# ['Chair_Type_1', 150000]
# ['Chair_Type_1', 130000]
# ['Chair_Type_1', 120000]
# ['Chair_Type_1', 180000]
# ['Chair_Type_1', 156000]
# ['Chair_Type_1', 135000]
# ['Chair_Type_1', 202500]
# ['Chair_Type_1', 175500]
# ['Chair_Type_1', 150000]
# ['Chair_Type_1', 225000]
# ['Chair_Type_1', 195000]
# ['Chair_Type_2', 100000]
# ['Chair_Type_2', 150000]
# ['Chair_Type_2', 130000]
# ['Chair_Type_2', 120000]
# ['Chair_Type_2', 180000]
# ['Chair_Type_2', 156000]
# ['Chair_Type_2', 135000]
# ['Chair_Type_2', 202500]
# ['Chair_Type_2', 175500]
# ['Chair_Type_2', 150000]
# ['Chair_Type_2', 225000]
# ['Chair_Type_2', 195000]
# ['Chair_Type_3', 100000]
# ['Chair_Type_3', 150000]
# ['Chair_Type_3', 130000]
# ['Chair_Type_3', 120000]
# ['Chair_Type_3', 180000]
# ['Chair_Type_3', 156000]
# ['Chair_Type_3', 135000]
# ['Chair_Type_3', 202500]
# ['Chair_Type_3', 175500]
# ['Chair_Type_3', 150000]
# ['Chair_Type_3', 225000]
# ['Chair_Type_3', 195000]
# ['Chair_Type_4', 100000]
# ['Chair_Type_4', 150000]
# ['Chair_Type_4', 130000]
# ['Chair_Type_4', 120000]
# ['Chair_Type_4', 180000]
# ['Chair_Type_4', 156000]
# ['Chair_Type_4', 135000]
# ['Chair_Type_4', 202500]
# ['Chair_Type_4', 175500]
# ['Chair_Type_4', 150000]
# ['Chair_Type_4', 225000]
# ['Chair_Type_4', 195000]

# %% [markdown]
# Use a list comprehension to obtain the same output. Store it in a variable called **sales_revenue**. <br/>
# Make sure you refrain from obtaining any inexistent "None" values.

# %%
sales_revenue = filter(None, [print([chair_type, price*quantity]) for chair_type in products_on_sale for price in sale_prices for quantity in quantities])
# Out:
# ['Chair_Type_1', 100000]
# ['Chair_Type_1', 150000]
# ['Chair_Type_1', 130000]
# ['Chair_Type_1', 120000]
# ['Chair_Type_1', 180000]
# ['Chair_Type_1', 156000]
# ['Chair_Type_1', 135000]
# ['Chair_Type_1', 202500]
# ['Chair_Type_1', 175500]
# ['Chair_Type_1', 150000]
# ['Chair_Type_1', 225000]
# ['Chair_Type_1', 195000]
# ['Chair_Type_2', 100000]
# ['Chair_Type_2', 150000]
# ['Chair_Type_2', 130000]
# ['Chair_Type_2', 120000]
# ['Chair_Type_2', 180000]
# ['Chair_Type_2', 156000]
# ['Chair_Type_2', 135000]
# ['Chair_Type_2', 202500]
# ['Chair_Type_2', 175500]
# ['Chair_Type_2', 150000]
# ['Chair_Type_2', 225000]
# ['Chair_Type_2', 195000]
# ['Chair_Type_3', 100000]
# ['Chair_Type_3', 150000]
# ['Chair_Type_3', 130000]
# ['Chair_Type_3', 120000]
# ['Chair_Type_3', 180000]
# ['Chair_Type_3', 156000]
# ['Chair_Type_3', 135000]
# ['Chair_Type_3', 202500]
# ['Chair_Type_3', 175500]
# ['Chair_Type_3', 150000]
# ['Chair_Type_3', 225000]
# ['Chair_Type_3', 195000]
# ['Chair_Type_4', 100000]
# ['Chair_Type_4', 150000]
# ['Chair_Type_4', 130000]
# ['Chair_Type_4', 120000]
# ['Chair_Type_4', 180000]
# ['Chair_Type_4', 156000]
# ['Chair_Type_4', 135000]
# ['Chair_Type_4', 202500]
# ['Chair_Type_4', 175500]
# ['Chair_Type_4', 150000]
# ['Chair_Type_4', 225000]
# ['Chair_Type_4', 195000]

# %% [markdown]
# **List comprehensions with Conditionals**
# <br> <br> **Conditional on the iterable**

# %% [markdown]
# Use a list comprehension to return a list with all even numbers between 1 and 10 inclusive, multiplied by 10.

# %%
ll_even = [nn*10 for nn in range(1,11) if nn % 2 == 0]
print(list(ll_even))
# Out:
# [20, 40, 60, 80, 100]

# %% [markdown]
# We consider the previous answer as the Pythonic way to obtain the output because it involved the use of a list comprehension.
# Can you think of a way to obtain identical output in the "Non-Pythonic" way, i.e. by using a double nested loop?

# %%
ll_even = []
for nn in range(1,11):
    if nn % 2 == 0:
        ll_even.append(nn*10)
print(ll_even)
# Out:
# [20, 40, 60, 80, 100]

# %% [markdown]
# **Conditional on the output**

# %% [markdown]
# Return a list that contains the element from range(1, 11) multiplied by 10 if the number is even, and "None" if that number is odd.

# %%
ll_even_none = [nn*10 if nn % 2 == 0 else None for nn in range(1,11)]
print(ll_even_none)
# Out:
# [None, 20, None, 40, None, 60, None, 80, None, 100]

# %% [markdown]
# ## Anonymous Functions

# %% [markdown]
# Define a function called **multiply_by_10** that will return a value ten times bigger than the argument.

# %%
def multiply_by_10(xx):
    return xx * 10

# %% [markdown]
# Apply **multiply_by_10** to the argument of 5. Clearly, you should obtain 50.

# %%
print(multiply_by_10(5))
# Out:
# 50

# %% [markdown]
# #### Lambda Functions

# %% [markdown]
# This time, create **multiply_by_10** as a Lambda funciton. Execute it with an argument of 7.

# %%
yy = (lambda xx: xx*10)(7)
print(yy)
# Out:
# 70

# %% [markdown]
# Define a Lambda function named **product_xy** that returns the product of two parameters, x and y. Execute it with arguments 4 and 20.

# %%
xy = (lambda x,y: x*y)(4,20)
print(xy)
# Out:
# 80

# %% [markdown]
# Create a Lambda function that returns the output of the following mathematical expression. Execute it with an argument of 3.
# <br> $$
# \frac{(135 - x^3)^4}{(1 + x)^5}
# $$

# %%
xx = (lambda x,y: ((135-x**3)**4)/y(x))(3, lambda z:(1+z)**5)
print(xx)
xx = (lambda x: ((135-x**3)**4)/((1+x)**5))(3)
print(xx)
# Out:
# 132860.25
# 132860.25
