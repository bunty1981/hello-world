# %% [markdown]
# ## Lists

# %% [markdown]
# Create a list, called "Numbers". Let it contain the numbers 10, 25, 40, and 50.

# %%
Numbers  = [10, 25, 40, 50]

# %% [markdown]
# Print the element at index 2 from the list.

# %%
print(Numbers[2])
# Out:
# 40

# %% [markdown]
# Print the 0th element.

# %%
print(Numbers[0])
# Out:
# 10

# %% [markdown]
# Print the third-to-last element using a minus sign in the brackets.

# %%
print(Numbers[-3])
# Out:
# 25

# %% [markdown]
# Substitute the number 10 with the number 15.

# %%
Numbers[0] = 15

# %% [markdown]
# Delete the number 25 from the Numbers list.

# %%
del Numbers[1]
print(Numbers)
# Out:
# [15, 40, 50]

# %% [markdown]
# ## Help Yourself with Methods

# %% [markdown]
# Append the number 100 to the Numbers list.

# %%
Numbers = [15, 40, 50]

# %%
Numbers.append(100)
print(Numbers)
# Out:
# [15, 40, 50, 100]

# %% [markdown]
# With the help of the "extend method", add the numbers 115 an 140 to the list.

# %%
Numbers.extend([115, 140])
print(Numbers)
# Out:
# [15, 40, 50, 100, 115, 140]

# %% [markdown]
# Print a statement, saying "The fourth element of the Numbers list is:" and then designate the value of the fourth element. Use a trailing comma.

# %%
print ("The fourt number is:", Numbers[3])
# Out:
# The fourt number is: 100

# %% [markdown]
# How many elements are there in the Numbers list?

# %%
print("There are ", len(Numbers), "numbers in the list.")
# Out:
# There are  6 numbers in the list.

# %% [markdown]
# ## List Slicing

# %%
Numbers = [15, 40, 50, 100, 115, 140]

# %% [markdown]
# Using list slicing, obtain the numbers 100 and 115.

# %%
num_sl = Numbers[3:5]
print("My numbers are ", num_sl)
# Out:
# My numbers are  [100, 115]

# %% [markdown]
# Using slicing, extract the first four elements from the list.

# %%
num_sl = Numbers[0:4]
print(num_sl)
# Out:
# [15, 40, 50, 100]

# %% [markdown]
# Using slicing, extract all the elements from the list from the 3rd position onwards.

# %%
num_sl = Numbers[3:]
print(num_sl)
# Out:
# [100, 115, 140]

# %% [markdown]
# Using slicing, extract the last 4 elements from the list.

# %%
num_sl = Numbers[-4:]
print("My numbers are ", num_sl)
# Out:
# My numbers are  [50, 100, 115, 140]

# %% [markdown]
# Which is the position of the value 15?

# %%
ii = 0
while ii < len(Numbers):
    if Numbers[ii] == 15:
        print("Found 15 at index:", ii)
        break
    ii += 1
# Out:
# Found 15 at index: 0

# %% [markdown]
# Create a list, called "Two_Numbers". Let its elements be the values 1 and 2. Then, create a new one, named "All_Numbers", that will containt both the "Numbers" and the "Two_Numbers" lists.

# %%
Two_Numbers = [1,2]
All_Numbers = Numbers + Two_Numbers
print(All_Numbers)
# Out:
# [15, 40, 50, 100, 115, 140, 1, 2]

# %% [markdown]
# Sort all the numbers in the "Numbers" list from the largest to the smallest.

# %%
Numbers.sort(reverse=True)
print(Numbers)
# Out:
# [140, 115, 100, 50, 40, 15]

# %% [markdown]
# ## Tuples

# %% [markdown]
# Create a tuple, called "Cars", with elements "BMW", "Dodge", and "Ford".

# %%
Cars = ("BMW", "Audi", "Toyota")

# %% [markdown]
# Access the second element of this tuple.

# %%
Cars[1]
# Out:
# 'Audi'

# %% [markdown]
# Call a method that would allow you to extract the provided name and age separately. Then print the "name" and "age" values to see if you worked correctly.

# %%
name, age = 'Peter,24'.split(',')

# %%
print(name, age)
# Out:
# Peter 24
# next line

# %% [markdown]
# Create a function that takes as arguments the two values of a rectangle and then returns the Area and the Perimeter of the rectangle.
# Call the function with arguments 2 and 10 to verify it worked correctly.

# %%
def rect_info(width, height):
    area = width * height
    perimeter = 2 * (width + height)
    return area, perimeter

rect_aa, rect_pp = rect_info(10, 5)
print(rect_aa, rect_pp)
# Out:
# 50 30

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# This is the menu of a close-by restaurant:

# %%
Menu = {'meal_1':'Spaghetti', 'meal_2':'Fries', 'meal_3':'Hamburger', 'meal_4':'Lasagna'}

# %% [markdown]
# What is the second meal in the list?

# %%
Menu['meal_2']
# Out:
# 'Fries'

# %% [markdown]
# Add a new meal - "Soup".

# %%
Menu['meal_5'] = "Soup"
print(Menu)
# Out:
# {'meal_1': 'Spaghetti', 'meal_2': 'Fries', 'meal_3': 'Hamburger', 'meal_4': 'Lasagna', 'meal_5': 'Soup'}

# %% [markdown]
# Replace the Hamburger with a Cheeseburger.

# %%
found = False
for key, val in Menu.items():
    if val == "Hamburger":
        found = True
        break

if not found:
    print("Hamburger is not in the menu.")
else:
    print("Hamburger is in the menu, with key: ", key)
# Out:
# Hamburger is in the menu, with key:  meal_3

# %% [markdown]
# Attach the Desserts list in the form of a sixth meal.

# %%
Dessert = ['Pancakes', 'Ice-cream', 'Tiramisu']

# %%
Menu['dessert'] = Dessert
print(Menu)
# Out:
# {'meal_1': 'Spaghetti', 'meal_2': 'Fries', 'meal_3': 'Hamburger', 'meal_4': 'Lasagna', 'meal_5': 'Soup', 'dessert': ['Pancakes', 'Ice-cream', 'Tiramisu']}

# %% [markdown]
# Create a new dictionary that contains the first five meals as keys and assign the following five values as prices (in dollars):
# 10, 5, 8, 12, 5.
# Start by *Price_list = {}*.

# %%
Price_list = {}
prices = [10.0, 5.0, 8.0, 12.0, 5.0]
ii=0;

for key, val in Menu.items():
    if key.split('_')[0] == 'meal':
        ii = int(key.split('_')[1])
        Price_list[val] = prices[ii-1]

print (Price_list)
# Out:
# {'Spaghetti': 10.0, 'Fries': 5.0, 'Hamburger': 8.0, 'Lasagna': 12.0, 'Soup': 5.0}

# %% [markdown]
# Use the *.get()* method to check the price of the Spaghetti.

# %%
Price_list.get('Spaghetti')
Price_list.get(Menu['meal_1'])
# Out:
# 10.0
