# %% [markdown]
# # Main section

# %%
# A simple two-line program:
xx= 1+5+7+10+21+33
print(xx)
# Out:
# 77

# %% [markdown]
# ## subsection

# %%
# Addtriples
(x,y,z) = (1,2,3)
print(x,y,z)
# Out:
# 1 2 3

# %%
#Assign more variables

(a,b,c,d) = (6,7,8,9)
print(a,b,c,d)
# Out:
# 6 7 8 9
